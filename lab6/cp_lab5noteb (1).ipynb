# %% [markdown]
# # Lab 6
# This is a jupyter notebook for lab 4. First we will import some libraries and functions.

# %%
import numpy as np
from netCDF4 import MFDataset 
from netCDF4 import Dataset 
import matplotlib
matplotlib.use('Agg')
import matplotlib.pylab as plt
from datetime import datetime
from netCDF4 import num2date
from netCDF4 import date2index
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import metpy.calc as mpcalc
from metpy.units import units
import xarray as xr
import cartopy.util as cutil
# %matplotlib inline

# %% [markdown]
# Our next setep is to read in the netCDF files.

# %%
ds = xr.open_dataset('https://psl.noaa.gov/psd/thredds/dodsC/Datasets/ncep.reanalysis.derived/pressure/air.mon.mean.nc')
ds2 = xr.open_dataset('https://psl.noaa.gov/psd/thredds/dodsC/Datasets/ncep.reanalysis.derived/pressure/hgt.mon.mean.nc')
ds3 = xr.open_dataset('https://psl.noaa.gov/psd/thredds/dodsC/Datasets/ncep.reanalysis.derived/pressure/uwnd.mon.mean.nc')
ds4 = xr.open_dataset('https://psl.noaa.gov/psd/thredds/dodsC/Datasets/ncep.reanalysis.derived/pressure/vwnd.mon.mean.nc')

# %% [markdown]
# Indicate the desired pressure level, year and month!

# %%
plevel = 500
year = 1970
month = 1
monthlabel = 'January'

years = [year]
while (years[-1] <= 2024):
    run_year = years[-1]

# These lines are needed for the indexing within Python 
# Don't change these!!
ty = int(run_year) - 1948
tm = int(month)-1

# %% [markdown]
# From the first file, we extract latitude, longitude and our variables of interest.

# %%
# Grab lat/lon values
lats = ds.lat.data
lons = ds.lon.data

#subtract 1 from tm because the first observation in Python is observation 0

temp = ds.air.sel(level=plevel)[tm::12,:,:]
hght = ds2.hgt.sel(level=plevel)[tm::12,:,:]
uwnd = np.asarray(ds3.uwnd.sel(level=plevel).values[tm::12,:,:] * units('m/s'))
vwnd = np.asarray(ds4.vwnd.sel(level=plevel).values[tm::12,:,:] * units('m/s'))
u_barbs = ds3.uwnd.sel(level=plevel).values[tm::12,:,:] * units('m/s')
v_barbs = ds4.vwnd.sel(level=plevel).values[tm::12,:,:] * units('m/s')


#hgt = f2.variables['hgt'][tm::12,5,:,:]

# %% [markdown]
# Print the numpy shapes of the temperature, latitude and longtitude. This can be important when debugging.

# %%
print (np.shape(hght))
print (np.shape(lats))
print (np.shape(lons))
# Out:
# (78, 73, 144)
# (73,)
# (144,)

# %% [markdown]
# Select the countour settings for the height anomalies (in m) and heights. The format is (minimum, maximum, interval)

# %%
clevs_hght_anom = np.arange(-180, 180.1, 30)
clevs_hght = np.arange(0, 8000, 60)

# %% [markdown]
# Make the map!

# %%
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 test
#
# NameError: name 'test' is not defined

# %%
import numpy as np
from netCDF4 import MFDataset 
from netCDF4 import Dataset 
import matplotlib
matplotlib.use('Agg')
import matplotlib.pylab as plt
from datetime import datetime, timedelta
from netCDF4 import num2date
from netCDF4 import date2index
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import metpy.calc as mpcalc
from metpy.units import units
import xarray as xr
import cartopy.util as cutil
# %matplotlib inline

ds = xr.open_dataset('https://psl.noaa.gov/psd/thredds/dodsC/Datasets/ncep.reanalysis.derived/pressure/air.mon.mean.nc')
ds2 = xr.open_dataset('https://psl.noaa.gov/psd/thredds/dodsC/Datasets/ncep.reanalysis.derived/pressure/hgt.mon.mean.nc')
ds3 = xr.open_dataset('https://psl.noaa.gov/psd/thredds/dodsC/Datasets/ncep.reanalysis.derived/pressure/uwnd.mon.mean.nc')
ds4 = xr.open_dataset('https://psl.noaa.gov/psd/thredds/dodsC/Datasets/ncep.reanalysis.derived/pressure/vwnd.mon.mean.nc')

plevel = 500
#year = 1950
month = 1
monthlabel = 'January'

# Grab lat/lon values
lats = ds.lat.data
lons = ds.lon.data



#subtract 1 from tm because the first observation in Python is observation 0
for year in range(1950,2025):
     
     # These lines are needed for the indexing within Python 
    # Don't change these!!
    ty = int(year) - 1948
    tm = int(month)-1
    
    temp = ds.air.sel(level=plevel)[tm::12,:,:]
    hght = ds2.hgt.sel(level=plevel)[tm::12,:,:]
    uwnd = np.asarray(ds3.uwnd.sel(level=plevel).values[tm::12,:,:] * units('m/s'))
    vwnd = np.asarray(ds4.vwnd.sel(level=plevel).values[tm::12,:,:] * units('m/s'))
    u_barbs = ds3.uwnd.sel(level=plevel).values[tm::12,:,:] * units('m/s')
    v_barbs = ds4.vwnd.sel(level=plevel).values[tm::12,:,:] * units('m/s')
    
    
    #hgt = f2.variables['hgt'][tm::12,5,:,:]
    
    
    
    clevs_hght_anom = np.arange(-300, 300.1, 30)
    clevs_hght = np.arange(0, 8000, 60)

    print(year)
    
    # Set up the projection that will be used for plotting
    mapcrs = ccrs.Robinson(central_longitude=180)
    
    # Set up the projection of the data; if lat/lon then PlateCarree is what you want
    datacrs = ccrs.PlateCarree()
    
    # Start the figure and create plot axes with proper projection
    fig = plt.figure(1, figsize=(14, 12))
    ax = plt.subplot(111, projection=mapcrs)
    
    #not needed here, but used for sub-setting domain to plot
    #ax.set_extent([-130, -72, 20, 55], ccrs.PlateCarree())
    
    # Add geopolitical boundaries for map reference
    ax.add_feature(cfeature.COASTLINE.with_scale('50m'))
    ax.add_feature(cfeature.STATES.with_scale('50m'))
    gl = ax.gridlines(color='gray',linewidth=2, alpha = 0.5, linestyle='--')
    
    # labels gridlines for PlateCarree ccrs option (doesn't work with Robinson, etc.)
    #gl.xlabels_top = False
    #gl.ylabels_right = False
    
    #color-filled contour time!
    #plotting temperature and including color bar
    cf = ax.contourf(lons, lats, hght[ty,:,:] - np.mean(hght[:,:,:],axis=0), clevs_hght_anom, cmap=plt.cm.RdYlBu_r, transform=datacrs)
    plt.colorbar(cf, orientation='horizontal', pad=0.05, aspect=50)
    
    # Plot 500-hPa Geopotential Height Anomaly in meters
    #cs = ax.contour(lons, lats, hght[ty,:,:] - np.mean(hght[:,:,:],axis=0), clevs_hght_anom, colors='black', transform=datacrs)
    #plt.clabel(cs, fmt='%d')
    
    # Plot 500-hPa Geopotential Heights in meters
    cs = ax.contour(lons, lats, hght[ty,:,:], clevs_hght, colors='black', transform=datacrs)
    plt.clabel(cs, fmt='%d')
    
    # Plot 500-hPa wind barbs in knots, regrid to reduce number of barbs
    ax.barbs(lons[::4], lats[::4], u_barbs.to('kt')[ty,::4,::4].m, 
             v_barbs.to('kt')[ty,::4,::4].m, pivot='middle',
             color='black', transform=datacrs, length=5, linewidth=0.4)
    
    # Make some nice titles for the plot (one right, one left)
    plt.title('500 hPa Z Anomaly ' + str(monthlabel) + ' ' +str(year))
    
    # Reduce excessive white space around image and show
    #plt.savefig('500hPaZAnomaly' + str(monthlabel) + str(year), dpi=150, bbox_inches='tight')
    #plt.show()
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /jupyterhq/miniconda3/envs/main/share/proj failed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 44
#      42 temp = ds.air.sel(level=plevel)[tm::12,:,:]
#      43 hght = ds2.hgt.sel(level=plevel)[tm::12,:,:]
# ---> 44 uwnd = np.asarray(ds3.uwnd.sel(level=plevel).values[tm::12,:,:] * units('m/s'))
#      45 vwnd = np.asarray(ds4.vwnd.sel(level=plevel).values[tm::12,:,:] * units('m/s'))
#      46 u_barbs = ds3.uwnd.sel(level=plevel).values[tm::12,:,:] * units('m/s')
#
# File /jupyterhq/miniconda3/envs/main/lib/python3.14/site-packages/xarray/core/dataarray.py:798, in DataArray.values(self)
#     785 @property
#     786 def values(self) -> np.ndarray:
#     787     """
#     788     The array's data converted to numpy.ndarray.
#     789
#    (...)    796     to this array may be reflected in the DataArray as well.
#     797     """
# --> 798     return self.variable.values
#
# File /jupyterhq/miniconda3/envs/main/lib/python3.14/site-packages/xarray/core/variable.py:556, in Variable.values(self)
#     553 @property
#     554 def values(self) -> np.ndarray:
#     555     """The variable's data as a numpy.ndarray"""
# --> 556     return _as_array_or_item(self._data)
#
# File /jupyterhq/miniconda3/envs/main/lib/python3.14/site-packages/xarray/core/variable.py:336, in _as_array_or_item(data)
#     322 def _as_array_or_item(data):
#     323     """Return the given values as a numpy array, or as an individual item if
#     324     it's a 0d datetime64 or timedelta64 array.
#     325
#    (...)    334     TODO: remove this (replace with np.asarray) once these issues are fixed
#     335     """
# --> 336     data = np.asarray(data)
#     337     if data.ndim == 0:
#     338         kind = data.dtype.kind
#
# File /jupyterhq/miniconda3/envs/main/lib/python3.14/site-packages/xarray/core/indexing.py:588, in ExplicitlyIndexed.__array__(self, dtype, copy)
#     583 def __array__(
#     584     self, dtype: DTypeLike | None = None, /, *, copy: bool | None = None
#     585 ) -> np.ndarray:
#     586     # Leave casting to an array up to the underlying array type.
#     587     if Version(np.__version__) >= Version("2.0.0"):
# --> 588         return np.asarray(self.get_duck_array(), dtype=dtype, copy=copy)
#     589     else:
#     590         return np.asarray(self.get_duck_array(), dtype=dtype)
#
# File /jupyterhq/miniconda3/envs/main/lib/python3.14/site-packages/xarray/core/indexing.py:954, in MemoryCachedArray.get_duck_array(self)
#     953 def get_duck_array(self):
# --> 954     duck_array = self.array.get_duck_array()
#     955     # ensure the array object is cached in-memory
#     956     self.array = as_indexable(duck_array)
#
# File /jupyterhq/miniconda3/envs/main/lib/python3.14/site-packages/xarray/core/indexing.py:908, in CopyOnWriteArray.get_duck_array(self)
#     907 def get_duck_array(self):
# --> 908     return self.array.get_duck_array()
#
# File /jupyterhq/miniconda3/envs/main/lib/python3.14/site-packages/xarray/coding/common.py:80, in _ElementwiseFunctionArray.get_duck_array(self)
#      79 def get_duck_array(self):
# ---> 80     return self.func(self.array.get_duck_array())
#
# File /jupyterhq/miniconda3/envs/main/lib/python3.14/site-packages/xarray/core/indexing.py:748, in LazilyIndexedArray.get_duck_array(self)
#     745 from xarray.backends.common import BackendArray
#     747 if isinstance(self.array, BackendArray):
# --> 748     array = self.array[self.key]
#     749 else:
#     750     array = apply_indexer(self.array, self.key)
#
# File /jupyterhq/miniconda3/envs/main/lib/python3.14/site-packages/xarray/backends/netCDF4_.py:117, in NetCDF4ArrayWrapper.__getitem__(self, key)
#     116 def __getitem__(self, key):
# --> 117     return indexing.explicit_indexing_adapter(
#     118         key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#     119     )
#
# File /jupyterhq/miniconda3/envs/main/lib/python3.14/site-packages/xarray/core/indexing.py:1140, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#    1118 """Support explicit indexing by delegating to a raw indexing method.
#    1119
#    1120 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)   1137 Indexing result, in the form of a duck numpy-array.
#    1138 """
#    1139 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1140 result = raw_indexing_method(raw_key.tuple)
#    1141 if numpy_indices.tuple:
#    1142     # index the loaded duck array
#    1143     indexable = as_indexable(result)
#
# File /jupyterhq/miniconda3/envs/main/lib/python3.14/site-packages/xarray/backends/netCDF4_.py:130, in NetCDF4ArrayWrapper._getitem(self, key)
#     128     with self.datastore.lock:
#     129         original_array = self.get_array(needs_lock=False)
# --> 130         array = getitem(original_array, key)
#     131 except IndexError as err:
#     132     # Catch IndexError in netCDF4 and return a more informative
#     133     # error message.  This is most often called when an unsorted
#     134     # indexer is used before the data is loaded from disk.
#     135     msg = (
#     136         "The indexing operation you are attempting to perform "
#     137         "is not valid on netCDF4.Variable object. Try loading "
#     138         "your data into memory first by calling .load()."
#     139     )
#
# KeyboardInterrupt:
